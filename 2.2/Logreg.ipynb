# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/home/jvfe/Downloads/2016 Stack Overflow Survey Responses.csv")
data = data.dropna()
data.shape
# Out:
# (15591, 66)

# %%
data.head()
# Out:
#      Unnamed: 0 collector    country               un_subregion so_region  \
# 187        1019  Facebook  Australia  Australia and New Zealand   Oceania
# 196       25993  Facebook  Australia  Australia and New Zealand   Oceania
# 197       26002  Facebook  Australia  Australia and New Zealand   Oceania
# 199       26469  Facebook  Australia  Australia and New Zealand   Oceania
# 200       27081  Facebook  Australia  Australia and New Zealand   Oceania
#
#     age_range  age_midpoint gender  \
# 187     40-49          44.5   Male
# 196     20-24          22.0   Male
# 197     20-24          22.0   Male
# 199     30-34          32.0   Male
# 200     30-34          32.0   Male
#
#                                    self_identification  \
# 187  Developer; Programmer; Sr. Developer; Guru; Ex...
# 196                        Developer; Engineer; Hacker
# 197                                         Programmer
# 199        Developer; Programmer; Full-stack Developer
# ...

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'collector',
#  'country',
#  'un_subregion',
#  'so_region',
#  'age_range',
#  'age_midpoint',
#  'gender',
#  'self_identification',
#  'occupation',
#  'occupation_group',
#  'experience_range',
#  'experience_midpoint',
#  'salary_range',
#  'salary_midpoint',
#  'big_mac_index',
#  'tech_do',
#  'tech_want',
#  'aliens',
#  'programming_ability',
#  'employment_status',
#  'industry',
#  'company_size_range',
#  'team_size_range',
#  'women_on_team',
#  'remote',
#  'job_satisfaction',
#  'job_discovery',
#  'dev_environment',
#  'commit_frequency',
#  'hobby',
#  'dogs_vs_cats',
#  'desktop_os',
#  'unit_testing',
#  'rep_range',
#  'visit_frequency',
#  'why_learn_new_tech',
#  'education',
#  'open_to_new_job',
#  'new_job_value',
#  'job_search_annoyance',
#  'interview_likelihood',
#  'how_to_improve_interview_process',
#  'star_wars_vs_star_trek',
#  'agree_tech',
#  'agree_notice',
#  'agree_problemsolving',
#  'agree_diversity',
#  'agree_adblocker',
# ...

# %%
data_clean = data[["remote", "company_size_range", "age_midpoint", "experience_midpoint"]]

data_clean
# Out:
#                        remote     company_size_range  age_midpoint  \
# 187    I rarely work remotely          1-4 employees          44.5
# 196    I rarely work remotely          I am not sure          22.0
# 197    I rarely work remotely          5-9 employees          22.0
# 199    I rarely work remotely          I am not sure          32.0
# 200          Part-time remote        20-99 employees          32.0
# ...                       ...                    ...           ...
# 55996        Part-time remote  5,000-9,999 employees          22.0
# 55997        Full-time remote      100-499 employees          54.5
# 55998  I rarely work remotely        20-99 employees          37.0
# 55999                   Never      100-499 employees          32.0
# 56000        Part-time remote      10,000+ employees          27.0
#
#        experience_midpoint
# 187                   13.0
# 196                    3.5
# 197                    1.5
# 199                    8.0
# ...

# %%
data_clean['remote'] = data_clean['remote'].replace(['Part-time remote','Full-time remote'], 'yes')
data_clean['remote'] = data_clean['remote'].replace(['Never', 'I rarely work remotely'], 'no')
data_clean
# Out:
#       remote     company_size_range  age_midpoint  experience_midpoint
# 187       no          1-4 employees          44.5                 13.0
# 196       no          I am not sure          22.0                  3.5
# 197       no          5-9 employees          22.0                  1.5
# 199       no          I am not sure          32.0                  8.0
# 200      yes        20-99 employees          32.0                 13.0
# ...      ...                    ...           ...                  ...
# 55996    yes  5,000-9,999 employees          22.0                  3.5
# 55997    yes      100-499 employees          54.5                 13.0
# 55998     no        20-99 employees          37.0                 13.0
# 55999     no      100-499 employees          32.0                  8.0
# 56000    yes      10,000+ employees          27.0                  3.5
#
# [15591 rows x 4 columns]

# %%
data_clean['remote'].value_counts()
# Out:
# no     11243
# yes     4348
# Name: remote, dtype: int64
