# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
plt.style.use('ggplot')

# %%
sisters = pd.read_csv("../../ml4-data/sisters.csv")
sisters
# Out:
#        age  sister  v116  v117  v118  v119  v120  v121  v122  v123  ...  v171  \
# 0       40   11545     5     2     2     2     4     4     4     5  ...     5
# 1       30   16953     4     1     4     4     1     1     1     5  ...     5
# 2       40   73323     2     2     5     5     3     4     2     3  ...     5
# 3       30   75339     4     3     3     4     3     4     2     4  ...     4
# 4       40   36303     4     2     3     5     1     4     4     4  ...     1
# ...    ...     ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 19273   30   84132     5     4     5     5     5     4     1     2  ...     2
# 19274   40    2424     1     4     5     3     4     5     1     4  ...     5
# 19275   50   84291     1     4     5     5     4     1     1     5  ...     5
# 19276   60   23493     5     2     5     4     2     1     1     5  ...     5
# 19277   80   91934     4     2     4     5     4     3     1     4  ...     5
#
# ...

# %%
plt.hist(sisters['age'], bins=range(min(sisters['age']), max(sisters['age']) + 10, 10))
# Out:
# (array([ 117., 5176., 4199., 2983., 3412., 2159., 1082.,  150.]),
#  array([ 20,  30,  40,  50,  60,  70,  80,  90, 100]),
#  <a list of 8 Patch objects>)

# %%
longsister = sisters.drop('sister',1).melt(id_vars=['age'], var_name='key')
longsister
# Out:
#          age   key  value
# 0         40  v116      5
# 1         30  v116      4
# 2         40  v116      2
# 3         30  v116      4
# 4         40  v116      4
# ...      ...   ...    ...
# 1253065   30  v180      4
# 1253066   40  v180      5
# 1253067   50  v180      1
# 1253068   60  v180      3
# 1253069   80  v180      4
#
# [1253070 rows x 3 columns]
